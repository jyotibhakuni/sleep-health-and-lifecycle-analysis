# %% [markdown]
# # SLEEP HEALTH AND STRESS LEVEL ANALYSIS

# %% [markdown]
# ## Description:
# The objective of this Stress level dataset is to analyse the various factors on which the stress level of a person depends like Age, Occupation, Quality of Sleep etc.
#
# URL of Dataset :- https://www.kaggle.com/datasets/uom190346a/sleep-health-and-lifestyle-dataset

# %% [markdown]
# ### Importing libraries like Numpy, Pandas, Matplotlib and Seaborn.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load the Dataset.

# %%
df = pd.read_csv('Sleep_health_and_lifestyle_dataset.csv')

# %% [markdown]
# ## Exploratory Data Analysis (EDA)
#
# Exploratory Data Analysis (EDA) is a step in the Data Analysis Process, where a number of techniques are used to better understand the dataset being used.
#
# In this step, we will perform the below operations:.1) Understandour VariabRead few record of the datasettGet t1.2) The shape of the da3.1.3) List types of all c 3.1.4) Info of the
#  3.1.5) Summary of the In et
#
# 3.2) Da we will checktT2.1) Check theT.2.2) Check the NULL values

# %%
#Read random five rows of the dataset 

df.sample(5)
# Out:
#      Person ID  Gender  Age Age Group  Occupation  Sleep Duration  \
# 10          11    Male   29     26-30      Doctor             6.1
# 35          36    Male   31     31-35      Doctor             6.1
# 327        328  Female   53     51-55    Engineer             8.5
# 101        102  Female   36     36-40     Teacher             7.2
# 116        117  Female   37     36-40  Accountant             7.2
#
#     Sleep Duration Range  Quality of Sleep  Physical Activity Level  \
# 10                   6-7                 6                       30
# 35                   6-7                 6                       30
# 327                  8-9                 9                       30
# 101                  7-8                 8                       60
# 116                  7-8                 8                       60
#
#      Stress Level BMI Category Blood Pressure  Heart Rate Heart Rate Range  \
# 10              8       Normal         120/80          70            66-70
# ...

# %%
#Number of rows and columns

df.shape
# Out:
# (374, 17)

# %%
#Type of all the columns

df.dtypes
# Out:
# Person ID                    int64
# Gender                      object
# Age                          int64
# Age Group                   object
# Occupation                  object
# Sleep Duration             float64
# Sleep Duration Range        object
# Quality of Sleep             int64
# Physical Activity Level      int64
# Stress Level                 int64
# BMI Category                object
# Blood Pressure              object
# Heart Rate                   int64
# Heart Rate Range            object
# Daily Steps                  int64
# Daily Steps Range           object
# Sleep Disorder              object
# dtype: object

# %%
#Summary of the dataset

df.describe()
# Out:
#         Person ID         Age  Sleep Duration  Quality of Sleep  \
# count  374.000000  374.000000      374.000000        374.000000
# mean   187.500000   42.184492        7.132086          7.312834
# std    108.108742    8.673133        0.795657          1.196956
# min      1.000000   27.000000        5.800000          4.000000
# 25%     94.250000   35.250000        6.400000          6.000000
# 50%    187.500000   43.000000        7.200000          7.000000
# 75%    280.750000   50.000000        7.800000          8.000000
# max    374.000000   59.000000        8.500000          9.000000
#
#        Physical Activity Level  Stress Level  Heart Rate   Daily Steps
# count               374.000000    374.000000  374.000000    374.000000
# mean                 59.171123      5.385027   70.165775   6816.844920
# std                  20.830804      1.774526    4.135676   1617.915679
# min                  30.000000      3.000000   65.000000   3000.000000
# ...

# %%
#Check if there are any NULL values

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                374 non-null    int64
#  1   Gender                   374 non-null    object
#  2   Age                      374 non-null    int64
#  3   Age Group                374 non-null    object
#  4   Occupation               374 non-null    object
#  5   Sleep Duration           374 non-null    float64
#  6   Sleep Duration Range     374 non-null    object
#  7   Quality of Sleep         374 non-null    int64
#  8   Physical Activity Level  374 non-null    int64
#  9   Stress Level             374 non-null    int64
#  10  BMI Category             374 non-null    object
#  11  Blood Pressure           374 non-null    object
#  12  Heart Rate               374 non-null    int64
#  13  Heart Rate Range         374 non-null    object
# ...

# %% [markdown]
# ## Data Cleaning

# %%
#replace the NULL values with given value

df['Sleep Disorder'].fillna('No Sleep Disorder', inplace=True)

# %%
#now there are no NULL values

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                374 non-null    int64
#  1   Gender                   374 non-null    object
#  2   Age                      374 non-null    int64
#  3   Age Group                374 non-null    object
#  4   Occupation               374 non-null    object
#  5   Sleep Duration           374 non-null    float64
#  6   Sleep Duration Range     374 non-null    object
#  7   Quality of Sleep         374 non-null    int64
#  8   Physical Activity Level  374 non-null    int64
#  9   Stress Level             374 non-null    int64
#  10  BMI Category             374 non-null    object
#  11  Blood Pressure           374 non-null    object
#  12  Heart Rate               374 non-null    int64
#  13  Heart Rate Range         374 non-null    object
# ...

# %%
#Drop the Collumns that are not required

df_cleaned = df.drop(['Sleep Disorder', 'Age', 'Sleep Duration', 'Heart Rate', 'Daily Steps'], axis=1)

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                374 non-null    int64
#  1   Gender                   374 non-null    object
#  2   Age Group                374 non-null    object
#  3   Occupation               374 non-null    object
#  4   Sleep Duration Range     374 non-null    object
#  5   Quality of Sleep         374 non-null    int64
#  6   Physical Activity Level  374 non-null    int64
#  7   Stress Level             374 non-null    int64
#  8   BMI Category             374 non-null    object
#  9   Blood Pressure           374 non-null    object
#  10  Heart Rate Range         374 non-null    object
#  11  Daily Steps Range        374 non-null    object
# dtypes: int64(4), object(8)
# memory usage: 35.2+ KB

# %%
df_cleaned.sample(5)
# Out:
#      Person ID  Gender Age Group  Occupation Sleep Duration Range  \
# 349        350  Female     56-60       Nurse                  8-9
# 80          81  Female     31-35   Scientist                  5-6
# 117        118  Female     36-40  Accountant                  7-8
# 335        336  Female     51-55    Engineer                  8-9
# 327        328  Female     51-55    Engineer                  8-9
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 349                 9                       75             3   Overweight
# 80                  4                       32             8   Overweight
# 117                 8                       60             4       Normal
# 335                 9                       30             3       Normal
# 327                 9                       30             3       Normal
#
#     Blood Pressure Heart Rate Range Daily Steps Range
# 349         140/95            66-70         6001-8000
# ...

# %%
df_cleaned.columns
# Out:
# Index(['Person ID', 'Gender', 'Age Group', 'Occupation',
#        'Sleep Duration Range', 'Quality of Sleep', 'Physical Activity Level',
#        'Stress Level', 'BMI Category', 'Blood Pressure', 'Heart Rate Range',
#        'Daily Steps Range'],
#       dtype='object')

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# ## Bar Graphs

# %%
stress_gender = df_cleaned.groupby(['Gender'], as_index=False)['Stress Level'].mean().sort_values(by='Stress Level', ascending=False)
sns.set(rc={'figure.figsize':(3,3)})
ax= sns.barplot(x = 'Gender', y= 'Stress Level' ,data = stress_gender,palette="viridis")

for bar in ax.containers:
    ax.bar_label(bar)

# %% [markdown]
# *From the above graph we can see that Stress Level of Males is more than that of Females.*

# %%
stress_age = df_cleaned.groupby(['Age Group'], as_index=False)['Stress Level'].mean().sort_values(by='Stress Level', ascending=False)
palette = sns.color_palette("viridis", len(stress_age))
ax = sns.barplot(x='Age Group', y='Stress Level', data=stress_age, palette=palette)
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.2f'), 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', 
                xytext = (0, 9), 
                textcoords = 'offset points')

plt.show()

# %% [markdown]
# *From the above graph we can see that Stress Level in the Age group of 46-50 years is maximum and it is minimum in the age group of 56-60 years.*

# %%
df_cleaned.columns
# Out:
# Index(['Person ID', 'Gender', 'Age Group', 'Occupation',
#        'Sleep Duration Range', 'Quality of Sleep', 'Physical Activity Level',
#        'Stress Level', 'BMI Category', 'Blood Pressure', 'Heart Rate Range',
#        'Daily Steps Range'],
#       dtype='object')

# %%
stress_occupation = df_cleaned.groupby(['Occupation'], as_index=False)['Stress Level'].mean().sort_values(by='Stress Level', ascending=False).head(10)
sns.set(rc={'figure.figsize':(15,5)})
ax= sns.barplot(x = 'Occupation', y= 'Stress Level' ,data = stress_occupation,palette="pastel")

for bar in ax.containers:
    ax.bar_label(bar)

# %%
stress_occupation = df_cleaned.groupby(['Occupation'], as_index=False)['Stress Level'].mean().sort_values(by='Stress Level', ascending=True).head(10)
sns.set(rc={'figure.figsize':(15,5)})
ax= sns.barplot(x = 'Occupation', y= 'Stress Level' ,data = stress_occupation,palette="Spectral")

for bar in ax.containers:
    ax.bar_label(bar)

# %% [markdown]
# *From the above graphs we can see that the people with Sales Representative as their occupation has the maximum Stress Level and Engineers have the minimum Stress Level.*

# %%
stress_sleep = df_cleaned.groupby(['Sleep Duration Range'], as_index=False)['Stress Level'].mean().sort_values(by='Stress Level', ascending=False)
sns.set(rc={'figure.figsize':(8,3)})
ax= sns.barplot(x = 'Sleep Duration Range', y= 'Stress Level' ,data = stress_sleep,palette="Spectral")

for bar in ax.containers:
    ax.bar_label(bar)

# %% [markdown]
# *From the above graph we can see that people with the sleep duration of 5-6 hours has the maximum stress level and people with the sleep duration of 8-9 hours has the minimum stress level.*

# %%
df_cleaned.columns
# Out:
# Index(['Person ID', 'Gender', 'Age Group', 'Occupation',
#        'Sleep Duration Range', 'Quality of Sleep', 'Physical Activity Level',
#        'Stress Level', 'BMI Category', 'Blood Pressure', 'Heart Rate Range',
#        'Daily Steps Range'],
#       dtype='object')

# %%
stress_bmi = df_cleaned.groupby(['BMI Category'], as_index=False)['Stress Level'].mean().sort_values(by='Stress Level', ascending=False)
sns.set(rc={'figure.figsize':(5,3)})
ax= sns.barplot(x = 'BMI Category', y= 'Stress Level' ,data = stress_bmi,palette="pastel")

for bar in ax.containers:
    ax.bar_label(bar)

# %% [markdown]
# *From the above graph we can see that the Overweight people has the maximum stress level and Normal people has the minimum stress level.*

# %%
stress_heart_rate = df_cleaned.groupby(['Heart Rate Range'], as_index=False)['Stress Level'].mean().sort_values(by='Stress Level', ascending=False)
sns.set(rc={'figure.figsize':(8,3)})
ax= sns.barplot(x = 'Heart Rate Range', y= 'Stress Level', data = stress_heart_rate,palette="coolwarm")

for bar in ax.containers:
    ax.bar_label(bar)

# %% [markdown]
# *From the above graph we can see that people with heart-rate between the range of 71-75 has the maximum stress level and people with 86-90 heart-rate range has the minimum stress level.*

# %%
stress_heart_rate = df_cleaned.groupby(['Blood Pressure'], as_index=False)['Stress Level'].mean().sort_values(by='Stress Level', ascending=False).head(15)
sns.set(rc={'figure.figsize':(15,5)})
ax= sns.barplot(x = 'Blood Pressure', y= 'Stress Level', data = stress_heart_rate,palette="colorblind")

for bar in ax.containers:
    ax.bar_label(bar)

# %%
stress_heart_rate = df_cleaned.groupby(['Blood Pressure'], as_index=False)['Stress Level'].mean().sort_values(by='Stress Level', ascending=True).head(15)
sns.set(rc={'figure.figsize':(15,5)})
ax= sns.barplot(x = 'Blood Pressure', y= 'Stress Level', data = stress_heart_rate)

for bar in ax.containers:
    ax.bar_label(bar)

# %% [markdown]
# *From the above graphs we can see that people with blood pressure between 131/86 has the maximum stress level and people with blood pressure between 115/78 has the minimum stress level.*

# %%
stress_heart_rate = df.groupby(['Sleep Disorder'], as_index=False)['Stress Level'].mean().sort_values(by='Stress Level', ascending=True)
sns.set(rc={'figure.figsize':(5,3)})
ax= sns.barplot(x = 'Sleep Disorder', y= 'Stress Level', data = stress_heart_rate,palette="muted")

for bar in ax.containers:
    ax.bar_label(bar)

# %% [markdown]
# *From the above graph we can see that people having Insomnia have more stress level than others.*

# %% [markdown]
# ## Pair Plot

# %%
df['Stress Level Binned'] = pd.qcut(df['Stress Level'], q=4, labels=["Low", "Medium", "High", "Very High"])
sns.pairplot(df[['Sleep Duration', 'Quality of Sleep', 'Physical Activity Level', 'Stress Level', 'Daily Steps', 'Stress Level Binned']], hue='Stress Level Binned', palette="Spectral")
plt.suptitle('Pairwise Relationships', y=1.02)
plt.show()
# Out:
# C:\Users\sanya\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# *The pairplot above displays the pairwise relationships between 'Sleep Duration', 'Quality of Sleep', 'Physical Activity Level', 'Stress Level', and 'Daily Steps', categorized by 'Stress Level Binned'.*

# %% [markdown]
# ## Analyzing relationships between variables

# %% [markdown]
# ## Correlation analysis
# Correlation analysis in data science is a statistical technique used to measure the strength and direction of the relationship between two or more variables in a dataset. It helps data scientists understand how changes in one variable are associated with changes in another

# %%
numeric_df = df.select_dtypes(include=['number'])
correlation_matrix = numeric_df.corr()
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# *The heatmap above shows the correlation between numeric variables in the dataset, highlighting their relationships and strengths.*

# %% [markdown]
# ## Conclusion

# %% [markdown]
# *Men aged 46-50 years who work as Sales Representatives, sleep for 5-6 hours, have an Overweight BMI, a heart rate between 71-75, and blood pressure between 131/86 exhibit the highest stress levels.*
